# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
import datetime
import pandas as pd
import lxml
import re

# %%
# utility functions 

# gets alt tags for images that are otherwise given in table as NaN, for levels and country
def getAlt(x):
    for img in x.find_all('img'):
        if(img.get("alt")):
#             print(img.get("alt"))
            img.string = img.get("alt")
    
def getLinkData(x):
    for a in x.find_all('a'):
        getAlt(a)
        
# gets the table data from the raw scraping, organizing lists of data for the icons and links
def getTableData(row):
    if('tr_header' in row.get_attribute_list('class')):
        return row.td.get_text()
    results = []
    for div in row.find_all('div'):
        a = div.find('a')
        img = a.find('img')
        val = {
            "link": a.get('href'),
            "text": a.get_text(),
            "image": img.get('src')
        }
        results.append(val)
        
    return results
            
# reorganizes the raw scraped data into a list of dictionaries
# with identical keys (to become columns)
def collapseHeaderRows(row_list, condensor_str):
    i = 0
    curr_grouping = row_list[i]
    updated_data_list = []
    while(i < len(row_list)):
        if(row_list[i] == str(row_list[i])):
            curr_grouping = row_list[i]
            row_list.remove(curr_grouping)
        else:
            for j in range(len(row_list[i])):
                row_list[i][j][condensor_str] = curr_grouping
                updated_data_list.append(row_list[i][j])
            i += 1
                
    return updated_data_list
        
# creates a DF from the reorganized data, with custom names for
# the values to combine (from the "header" row above the list of items in the table) and
# the "text" of those items (may be "Factions", "Unit Types", etc.)
def createDFfromRowData(row_data, condensor_str, text_name):
    header = row_data.pop(0)
    row_data_condensed = collapseHeaderRows(row_data, condensor_str)

    return pd.DataFrame(data={
        condensor_str:[a[condensor_str] for a in row_data_condensed],
        text_name: [a["text"] for a in row_data_condensed],
        "link": [a["link"] for a in row_data_condensed],
        "image": [a["image"] for a in row_data_condensed],
    })

# %%
# start by getting data for each playable faction, then add unit scraping on top of it (helper function later)
def getCoursesData():
    base_url = "https://www.udacity.com"
    url = base_url + "/courses/all"

    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=False)

    browser.visit(url)
    
    #add a delay so page fully loads
    time.sleep(6)
    
    courses = []
    
    try:
        current_course_catalog = browser.html

        news_soup = bs(current_course_catalog, "html.parser")

        available_courses = news_soup.find(class_=re.compile("^catalog.*"))
        print(len(available_courses))

        
        for i, course in enumerate(available_courses.find_all("li")):
            course_type = course.find(class_=re.compile("^card_flag.*")).get_text()
            course_title = course.find(class_=re.compile("^card_title.*")).get_text()
            course_desc = course.find(class_=re.compile("^card_summary.*")).get_text()
            details = course.find_all(class_=re.compile("^card_detailContent.*"))
            course_level = course.find(class_=re.compile("^card_level.*")).get_text()
            course_duration = course.find(class_=re.compile("^card_duration.*")).get_text()
            
            try:
                course_skills_covered = details[0].get_text()
                course_prerequisites = details[1].get_text()
            except:
                course_prerequisites = None
                pass
            
            rating = None
            review_count = None
            try:
                rating = float(course.find(class_=re.compile("^rating-stars_visuallyHidden.*")).get_text().split(" ")[0])
                review_count = int(course.find(class_=re.compile("^card_reviewCount.*")).get_text().split(" ")[0])
            except:
                pass
            
            affiliates = None
            try:
                affiliates = course.find(class_=re.compile("^card_affiliatesContent.*")).get_text()
            except:
                pass
            
            link = base_url + course.find("a")["href"]
            
            courses.append((course_title, course_type, course_desc, course_level, course_duration, rating, review_count, course_skills_covered, course_prerequisites, affiliates, link))
            
    except:
        print("Something went wrong!")
        
    
    browser.quit()

    return courses

# %%
#get basic playable faction data (by scraping honga.net)
# output_df = getFactionsData()

# output_df

courses = getCoursesData()
courses
# Out:
# 3
# [('Data Engineering with AWS',
#   'nanodegree',
#   'Learn to design data models, build data warehouses and data lakes, automate data pipelines, and manage massive datasets.',
#   'intermediate',
#   '4 Months',
#   4.6,
#   1802,
#   'AWS Glue,  Amazon S3,  AWS Data Warehouse,  Redshift,  Apache Airflow,  Data Pipeline DAGs,  Data Extraction,  Data Pipeline Creation,  ETL,  OLAP Cubes,  Data Warehouse Architecture,  Cloud Computing Fluency,  Data Pipeline Maintenance',
#   'Intermediate Python, intermediate SQL & command line',
#   None,
#   'https://www.udacity.com/course/data-engineer-nanodegree--nd027'),
#  ('Product Manager',
#   'nanodegree',
#   'Envision and execute the development of industry-defining products, and learn how to successfully bring them to market.',
#   'beginner',
#   '4 Months',
#   4.7,
#   864,
#   'Product Strategy, Product Design, Product Development, Design Sprint, Product Launch',
#   'No Experience Required',
#   None,
#   'https://www.udacity.com/course/product-manager-nanodegree--nd036'),
#  ('C++',
#   'nanodegree',
#   'Get hands-on experience building five real-world projects in this popular general-purpose programming language.',
#   'intermediate',
#   '4 Months',
#   4.5,
#   1126,
#   'Data Structures & Algorithms, Memory Management, Concurrency, Object-oriented Programming, C++',
#   'Intermediate Programming',
#   None,
#   'https://www.udacity.com/course/c-plus-plus-nanodegree--nd213'),
#  ('Business Analytics',
#   'nanodegree',
#   'Gain foundational data skills like analyzing data, modeling business scenarios, and communicating findings.',
#   'beginner',
#   '3 Months',
#   4.8,
#   2649,
#   'Excel & Spreadsheets, SQL, Data Visualization, Data Dashboards',
#   'None',
#   'Mode',
#   'https://www.udacity.com/course/business-analytics-nanodegree--nd098'),
#  ('Data Scientist',
#   'nanodegree',
#   'Build effective machine learning models, run data pipelines, build recommendation systems, and deploy solutions to the cloud with industry-aligned projects.',
#   'advanced',
#   '4 Months',
#   4.7,
#   1212,
#   'Machine Learning, Deep Learning, Software Engineering',
#   'Python, SQL & Statistics',
#   'Bertelsmann, Figure Eight, IBM Watson, Insight, Kaggle, Starbucks',
#   'https://www.udacity.com/course/data-scientist-nanodegree--nd025'),
#  ('Introduction to Programming',
#   'nanodegree',
#   'A first step for beginners towards careers in web and app development, machine learning, data science, AI, and more.',
#   'beginner',
#   '4 Months',
#   4.7,
#   3865,
#   'Front-End Development Basics,  HTML,  CSS,  Python Syntax,  Text Processing in Python,  DevTools,  Command Line Interface Basics,  Code Debugging,  Basic JavaScript scripts,  JavaScript Functions,  JavaScript arrays,  JavaScript objects',
#   'No coding experience needed',
#   None,
#   'https://www.udacity.com/course/intro-to-programming-nanodegree--nd000'),
#  ('Digital Marketing',
#   'nanodegree',
#   'Meet the growing demand for skilled digital marketers by learning the latest technologies for building impactful marketing strategies.\n',
#   'beginner',
#   '3 Months',
#   4.7,
#   2418,
#   'Digital Marketing,  Marketing fundamentals,  Google Analytics,  Social Media Marketing,  Facebook Marketing,  Search Engine Optimization,  Search Engine Marketing,  Digital marketing metrics,  Display Ads,  Video advertising,  Email marketing,  Branding strategy',
#   'No Experience Required.',
#   None,
#   'https://www.udacity.com/course/digital-marketing-nanodegree--nd018'),
#  ('Data Analyst',
#   'nanodegree',
#   'Use Python, SQL, and statistics to uncover insights, communicate critical findings, and create data-driven solutions.',
#   'intermediate',
#   '4 Months',
#   4.6,
#   3496,
#   'Data Wrangling, Matplotlib, Bootstrapping, Pandas & NumPy, Statistics',
#   'Python & SQL',
#   'Kaggle',
#   'https://www.udacity.com/course/data-analyst-nanodegree--nd002'),
#  ('Deep Learning',
#   'nanodegree',
#   'Deep learning is driving advances in artificial intelligence that are changing our world—enroll now and learn to build and apply your own deep neural networks.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   3368,
#   'Neural Networks,  Perceptron,  Autoencoders,  Convolutional Neural Networks,  PyTorch,  Object Detection,  Recurrent Neural Networks,  Long-short term Memory Networks,  Backpropagation,  Generative Adversarial Networks,  Deep Learning Techniques,  Image Generation,  Hyperparameter Tuning',
#   'Intermediate Python',
#   None,
#   'https://www.udacity.com/course/deep-learning-nanodegree--nd101'),
#  ('Programming for Data Science with Python',
#   'nanodegree',
#   'Learn the fundamental programming tools for data professionals: Python, SQL, terminal, and Git.',
#   'beginner',
#   '3 Months',
#   4.7,
#   1558,
#   'Python, Numpy & Pandas, SQL, Git & GitHub',
#   'None',
#   'Mode',
#   'https://www.udacity.com/course/programming-for-data-science-nanodegree--nd104'),
#  ('Full Stack Web Developer',
#   'nanodegree',
#   'Learn to design and develop powerful modern web applications that form the foundation for the apps, websites, and systems that people and businesses use every day.',
#   'intermediate',
#   '4 Months',
#   4.5,
#   749,
#   'Python, JavaScript, PostgreSQL, Flask, Docker, Kubernetes',
#   'Prior experience with Python, CSS/HTML, and Git',
#   None,
#   'https://www.udacity.com/course/full-stack-web-developer-nanodegree--nd0044'),
#  ('AWS Machine Learning Engineer',
#   'nanodegree',
#   'Learn the data science and machine learning skills required to build and deploy machine learning models in production using Amazon SageMaker.',
#   'intermediate',
#   '5 Months',
#   4.7,
#   143,
#   'Feature Engineering,  Machine Learning Fluency,  Data Loading with SageMaker,  Amazon S3,  Neural Network Basics,  Deep Learning Fluency,  Hyperparameter Tuning,  Machine Learning Framework Fundamentals,  SageMaker JumpStart,  Cloud Resource Allocation,  Distributed Model Training with SageMaker,  AWS Lambda ',
#   'Basic knowledge of machine learning algorithms and Python programming',
#   'AWS',
#   'https://www.udacity.com/course/aws-machine-learning-engineer-nanodegree--nd189'),
#  ('SQL',
#   'nanodegree',
#   'Master SQL, the core language for big data analysis, to enable insight-driven decision-making and strategy.',
#   'beginner',
#   '2 Months',
#   4.6,
#   339,
#   'SQL, PostgreSQL, JOINs, Subqueries, Window Functions, Partitions, Data Cleaning, DDL, DML, Relational and Non-Relational Databases',
#   'Basic understanding of data types',
#   None,
#   'https://www.udacity.com/course/learn-sql--nd072'),
#  ('Machine Learning DevOps Engineer',
#   'nanodegree',
#   'Gain the DevOps skills required to automate the various aspects and stages of building and monitoring machine learning models.',
#   'advanced',
#   '4 Months',
#   4.6,
#   115,
#   'API development,  Automated model scoring,  CI/CD,  Model testing,  Data Version Control,  Machine Learning Pipelines',
#   'Prior experience with Python and Machine Learning',
#   None,
#   'https://www.udacity.com/course/machine-learning-dev-ops-engineer-nanodegree--nd0821'),
#  ('Artificial Intelligence for Trading',
#   'nanodegree',
#   'Complete real-world projects designed by industry experts, covering topics from asset management to trading signal generation. Master AI algorithms for trading, and build your career-ready portfolio.',
#   'intermediate',
#   '6 Months',
#   4.6,
#   789,
#   'Momentum Trading Strategy, Smart Beta, Alpha Factors, Natural Language Processing, Deep Learning, Neural Networks',
#   'Python & Mathematics',
#   'WorldQuant',
#   'https://www.udacity.com/course/ai-for-trading--nd880'),
#  ('React',
#   'nanodegree',
#   'Learn to build declarative user interfaces for the web with React as well as manage state more predictably in your applications with Redux.',
#   'intermediate',
#   '2 Months',
#   4.7,
#   1269,
#   'React Component State,  React Router,  React Hooks,  JavaScript Functions,  Application State Management with Redux,  React-Redux Bindings,  React Component State,  Fetching Data,  React Native Basics,  Data Lifecycle Management,  Jest,  React-Redux Bindings,  React Design Patterns,  Software Testing',
#   'HTML & CSS, JavaScript, Asynchronous JavaScript (AJAX) and Web forms',
#   None,
#   'https://www.udacity.com/course/react-nanodegree--nd019'),
#  ('Self-Driving Car Engineer',
#   'nanodegree',
#   'Learn the techniques that power self-driving cars across the full stack of a vehicle’s autonomous capabilities.',
#   'advanced',
#   '5 Months',
#   None,
#   None,
#   'Computer Vision, Deep Learning, Sensor Fusion, Localization, Self-Driving Cars, Path Planning and Control',
#   'Python, C++, Linear Algebra and Calculus',
#   'Waymo, Mercedes-Benz',
#   'https://www.udacity.com/course/self-driving-car-engineer-nanodegree--nd0013'),
#  ('UX Designer',
#   'nanodegree',
#   'Design impactful user experiences for products in today’s digital world.',
#   'beginner',
#   '3 Months',
#   4.7,
#   1032,
#   'User Research, User Experience, Prototyping, Interactive Design, User Interface Design, Usability Testing',
#   'No Experience Required.',
#   None,
#   'https://www.udacity.com/course/ux-designer-nanodegree--nd578'),
#  ('Java Developer',
#   'nanodegree',
#   'Learn back-end development with Java, one of the most popular programming languages in the world.',
#   'intermediate',
#   '4 Months',
#   4.5,
#   359,
#   'Java, Spring Boot, Rest API, MySQL, MongoDB',
#   'Intermediate knowledge of Java',
#   None,
#   'https://www.udacity.com/course/java-developer-nanodegree--nd035'),
#  ('Data Engineering with Microsoft Azure ',
#   'nanodegree',
#   'Master job-ready Azure skills like designing data models and utilizing other in-demand components of the cloud computing service.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Database Normalization,  Data Modeling Basics,  PostgreSQL,  SQL and SQL scripting, Denormalized Data Schemas,  Relational data modeling,  OLAP Cubes,  Data Warehouse Architecture,  Data Extraction,  Big Data Fluency,  Apache Spark,  Data Lakes,  Apache Airflow,  Azure Pipelines\n',
#   'Experience with SQL, Python, Azure, and Github',
#   None,
#   'https://www.udacity.com/course/data-engineering-with-microsoft-azure-nanodegree--nd0277'),
#  ('AI Programming with Python',
#   'nanodegree',
#   'Learn Python, NumPy, pandas, Matplotlib, PyTorch, calculus, and linear algebra—the foundations for building your own neural network.',
#   'beginner',
#   '3 Months',
#   4.7,
#   1626,
#   'Python, NumPy, Pandas, Matplotlib, PyTorch',
#   'Basic Algebra and Programming Knowledge',
#   None,
#   'https://www.udacity.com/course/ai-programming-python-nanodegree--nd089'),
#  ('Data Product Manager',
#   'nanodegree',
#   'Apply data science best practices to build products that deliver the right experience to the right users—at the right time.',
#   'intermediate',
#   '3 Months',
#   4.3,
#   220,
#   'Data Science, Product Management, Product Design, Data Visualization, User Journey Maps',
#   'Prior Data Analysis & Product Management Experience Recommended',
#   None,
#   'https://www.udacity.com/course/data-product-manager-nanodegree--nd030'),
#  ('Intermediate Python',
#   'nanodegree',
#   'Learn how to plan, design, and implement enterprise data infrastructure solutions and create the blueprints for your organization’s data success.',
#   'intermediate',
#   '2 Months',
#   4.4,
#   144,
#   'Python, Object-oriented programming, Modular code, Python Package Index',
#   'Basic Python',
#   None,
#   'https://www.udacity.com/course/intermediate-python-nanodegree--nd303'),
#  ('Growth Product Manager',
#   'nanodegree',
#   'Lead experimentation and data-driven decision-making to drive products to the next level of scale, impact, and profitability.',
#   'intermediate',
#   '3 Months',
#   4.5,
#   50,
#   'Acquisition Strategy,  Growth Loops,  Product Management,  Activation Metrics,  Growth Strategy,  Activation Strategy,  Product Monetization Strategy,  Product Monetization Metrics,  Premium Value,  Cohort Analysis,  Experiment Design,  Target Personas,  Customer Acquisition Cost,  User Journey Maps',
#   'Prior Product Management Experience recommended',
#   None,
#   'https://www.udacity.com/course/growth-product-manager-nanodegree--nd037'),
#  ('Front End Web Developer',
#   'nanodegree',
#   'Learn how to build high quality websites and dynamic applications to create stunning user experiences for the web.',
#   'intermediate',
#   '4 Months',
#   4.6,
#   1194,
#   'JavaScript, HTML, CSS, Webpack, Flexbox, Node, Object-oriented Programming',
#   'Knowledge of basic HTML, CSS, and JavaScript',
#   None,
#   'https://www.udacity.com/course/front-end-web-developer-nanodegree--nd0011'),
#  ('Blockchain Developer',
#   'nanodegree',
#   "Demand for blockchain developers is skyrocketing. In this program, you'll work with the Bitcoin and Ethereum protocols, build projects for real-world application, and gain the essential skills for a career in this dynamic space.",
#   'intermediate',
#   '4 Months',
#   4.5,
#   566,
#   'Ethereum Blockchain, Blockchain Architecture, Data Auditing',
#   'Object-oriented programming',
#   None,
#   'https://www.udacity.com/course/blockchain-developer-nanodegree--nd1309'),
#  ('Deep Reinforcement Learning',
#   'nanodegree',
#   'Master the deep reinforcement learning skills that are powering amazing advances in AI—and start applying these skills to applications like video games and robotics.',
#   'advanced',
#   '3 Months',
#   4.6,
#   534,
#   'Reinforcement Learning, Neural Networks, PyTorch, Deep Q-Networks (DQN), Deep Deterministic Policy Gradients (DDPG)',
#   'Experience with Python, Probability, Machine Learning, & Deep Learning.',
#   'Unity, Nvidia Deep Learning Institute',
#   'https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893'),
#  ('Computer Vision',
#   'nanodegree',
#   'Learn the in-demand skills of computer vision, a growing field of AI, that empower advancements in robotics and automation.',
#   'advanced',
#   '3 Months',
#   4.7,
#   798,
#   'Convolutional Neural Networks, Recurrent Neural Networks, Simultaneous Localization and Mapping, Object Tracking, Image Classification, Deep Learning',
#   'Python, Statistics, Machine Learning, & Deep Learning',
#   'Affectiva, Nvidia Deep Learning Institute',
#   'https://www.udacity.com/course/computer-vision-nanodegree--nd891'),
#  ('Data Structures and Algorithms',
#   'nanodegree',
#   'Get hands-on practice with over 100 data structures and algorithm exercises with technical mentor support when needed to help prepare you for the workplace.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   850,
#   'Data Structures and Algorithms, Problem Solving, Interview Practice Problems, Python',
#   'Python and Basic Algebra',
#   None,
#   'https://www.udacity.com/course/data-structures-and-algorithms-nanodegree--nd256'),
#  ('Robotics Software Engineer',
#   'nanodegree',
#   'Build five hands-on projects to acquire core robotics software engineering skills: ROS, Gazebo, localization, mapping, SLAM, navigation, and path planning.',
#   'advanced',
#   '4 Months',
#   4.5,
#   571,
#   'C++, ROS, Localization, Mapping, SLAM, Navigation, Path Planning, Robot Operating System, Robotics',
#   'Mathematics & Programming',
#   None,
#   'https://www.udacity.com/course/robotics-software-engineer--nd209'),
#  ('AI Product Manager',
#   'nanodegree',
#   'Develop AI products that deliver real business value by building skills that help you compete in the new AI-powered world.',
#   'beginner',
#   '2 Months',
#   4.4,
#   616,
#   'AI Products, Training ML Models, Annotating Datasets, Prototyping a Product',
#   'No Experience Required',
#   'Appen',
#   'https://www.udacity.com/course/ai-product-manager-nanodegree--nd088'),
#  ('Android Kotlin Developer',
#   'nanodegree',
#   'Master Android app development with Kotlin, a modern programming language that enables developers to be more productive.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   355,
#   'Android Development, Kotlin, Android Studio, Gradle, RESTful interfaces, Web APIs, App Architecture, Databases, Custom Views, Notifications, Location Services, Testing, Firebase',
#   'Experience with Object-Oriented Programming',
#   'Google',
#   'https://www.udacity.com/course/android-kotlin-developer-nanodegree--nd940'),
#  ('Java Programming',
#   'nanodegree',
#   'Elevate your Java abilities with the fundamental skills used by developers to design, code, test, and deploy cutting-edge Java software.',
#   'intermediate',
#   '3 Months',
#   4.5,
#   143,
#   'Object-oriented programming,  functional programming,  I/O,  reflection,  concurrent programming,  Java modules',
#   'Basic programming concepts like variables, loops and conditionals.',
#   None,
#   'https://www.udacity.com/course/java-programming-nanodegree--nd079'),
#  ('Cloud DevOps Engineer',
#   'nanodegree',
#   'Companies are looking for talented DevOps engineers to remain competitive in this agile world. Enroll now to master skills like operationalizing infrastructure at scale and delivering applications and services at high velocity.',
#   'intermediate',
#   '4 Months',
#   4.6,
#   846,
#   'AWS, Configuration Management with Ansible, Continuous Integration / Continuous Deployment, Microservices with Kubernetes, CloudFormation',
#   'Intermediate JavaScript',
#   None,
#   'https://www.udacity.com/course/cloud-dev-ops-nanodegree--nd9991'),
#  ('Data Architect',
#   'nanodegree',
#   'Learn how to plan, design and implement enterprise data infrastructure solutions and create the blueprints for your organization’s data success.',
#   'advanced',
#   '4 Months',
#   4.6,
#   122,
#   'Entity relationship diagrams,  Relational Data Design,  Online Analytical Processing,  Operational Data Stores,  Data Lake Architecture,  Data Governance\n',
#   'Intermediate Python, SQL, and Basics of ETL/Data Pipelines',
#   None,
#   'https://www.udacity.com/course/data-architect-nanodegree--nd038'),
#  ('Data Analysis and Visualization with Microsoft Power BI',
#   'nanodegree',
#   'Utilize Microsoft Power BI as a primary tool for data pre-processing, visualization, and analysis.',
#   'beginner',
#   '3 Months',
#   4.7,
#   256,
#   'Power BI,  data visulations,  data modeling,  Extract-Transform-Load,  Data Analytics Expressions',
#   'Microsoft Excel',
#   None,
#   'https://www.udacity.com/course/data-analysis-and-visualization-with-power-BI-nanodegree--nd331'),
#  ('Natural Language Processing',
#   'nanodegree',
#   'Learn the job-ready skills that progress computers to be able to understand, process, and respond to human language.',
#   'advanced',
#   '3 Months',
#   4.5,
#   525,
#   'Machine Learning, Speech Recognition, Sentiment Analysis, Machine Translation, Part of Speech Tagging',
#   'Python, Statistics, Machine Learning, & Deep Learning',
#   'Amazon Alexa, IBM Watson',
#   'https://www.udacity.com/course/natural-language-processing-nanodegree--nd892'),
#  ('Intro to Self-Driving Cars',
#   'nanodegree',
#   'This introductory program is the perfect way to start your journey into the future of transportation—flying cars.',
#   'intermediate',
#   '4 Months',
#   4.6,
#   806,
#   'Computer Vision, Machine Learning, Vehicle Motion, Control',
#   'Programming & Mathematics',
#   None,
#   'https://www.udacity.com/course/intro-to-self-driving-cars--nd113'),
#  ('Full Stack JavaScript Developer',
#   'nanodegree',
#   'Find success as a full stack developer by focusing on topics like UI, UX, APIs, server side business logic, persistence layers, and more.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   89,
#   'Creating an API,  Databases and SQL,  Node.js,  Angular,  TypeScript,  Deployment',
#   'HTML, CSS, Basic JavaScript, JSON',
#   None,
#   'https://www.udacity.com/course/full-stack-javascript-developer-nanodegree--nd0067'),
#  ('Introduction to Cybersecurity',
#   'nanodegree',
#   'Get your start in the high growth field of cybersecurity by building foundational skills including evaluating, maintaining, and monitoring the security of computer systems.',
#   'beginner',
#   '4 Months',
#   4.5,
#   163,
#   'Threat Assessment, Security Vulnerabilities, Compliance, Governance, Risk, Incident Response',
#   'Basic knowledge of network connectivity and OS fundamentals',
#   'SecurityScorecard',
#   'https://www.udacity.com/course/intro-to-cybersecurity-nanodegree--nd545'),
#  ('Data Streaming',
#   'nanodegree',
#   'Learn how to stream data to unlock key insights in real-time.',
#   'advanced',
#   '2 Months',
#   4.3,
#   242,
#   'Data Streaming, Spark, Kafka, Kafka Streaming, Spark Streaming',
#   'Intermediate Python, SQL, and experience with ETL',
#   None,
#   'https://www.udacity.com/course/data-streaming-nanodegree--nd029'),
#  ('Cloud Developer',
#   'nanodegree',
#   'Cloud development is the foundation for the new world of software development. Enroll now to build and deploy production-ready full stack apps at scale on AWS.',
#   'intermediate',
#   '4 Months',
#   4.5,
#   844,
#   'AWS, Microservices, Serverless Architecture, Kubernetes',
#   'Intermediate JavaScript',
#   None,
#   'https://www.udacity.com/course/cloud-developer-nanodegree--nd9990'),
#  ('Intro to Machine Learning with TensorFlow',
#   'nanodegree',
#   'Build a solid foundation in supervised, unsupervised, and deep learning. Then, use these skills to test and deploy machine learning models in a production environment.',
#   'intermediate',
#   '3 Months',
#   4.7,
#   529,
#   'TensorFlow, Deep Learning, scikit-learn, Supervised Learning, Unsupervised Learning',
#   'Intermediate Python',
#   'Kaggle, AWS',
#   'https://www.udacity.com/course/intro-to-machine-learning-with-tensorflow-nanodegree--nd230'),
#  ('Sensor Fusion Engineer',
#   'nanodegree',
#   'Learn to fuse lidar point clouds, radar signatures, and camera images using Kalman Filters to detect and track vehicles and pedestrians over time.',
#   'advanced',
#   '4 Months',
#   4.7,
#   301,
#   'Perception, Lidar, Radar, Sensors, Computer Vision',
#   'Intermediate C++, Calculus, and Probability',
#   'Mercedes-Benz',
#   'https://www.udacity.com/course/sensor-fusion-engineer-nanodegree--nd313'),
#  ('Predictive Analytics For Business',
#   'nanodegree',
#   'Learn essential AI concepts including search, optimization, planning, pattern recognition, and more from experts like Peter Norvig and Sebastian Thrun.',
#   'beginner',
#   '3 Months',
#   4.7,
#   554,
#   'Data Wrangling, Classification, A/B Testing, Forecasting, Segmentation',
#   'Algebra, Descriptive Statistics, and Excel',
#   'Alteryx',
#   'https://www.udacity.com/course/predictive-analytics-for-business-nanodegree--nd008t'),
#  ('Intermediate JavaScript',
#   'nanodegree',
#   'Master JavaScript, the most popular programming language in the world. Be equipped for advanced roles in web development, server-side application development, and desktop development.',
#   'intermediate',
#   '3 Months',
#   4.5,
#   161,
#   'Functional Programming, DOM, Data Structures, Asynchronous Programming, Synchronous Programming',
#   'Basic JavaScript',
#   None,
#   'https://www.udacity.com/course/intermediate-javascript-nanodegree--nd032'),
#  ('Agile Software Development',
#   'nanodegree',
#   'Get equipped with the skills you need to guide the delivery of high value products with top notch software development teams.\n',
#   'beginner',
#   '3 Months',
#   4.7,
#   151,
#   'Agile, Scrum, Kanban, XP, Minimum Viable Product',
#   'No Experience Required',
#   'ThoughtWorks',
#   'https://www.udacity.com/course/agile-software-development-nanodegree--nd144'),
#  ('Intro to Machine Learning with PyTorch',
#   'nanodegree',
#   'Build a solid foundation in supervised, unsupervised, and deep learning. Then, use these skills to test and deploy machine learning models in a production environment.',
#   'intermediate',
#   '3 Months',
#   4.7,
#   446,
#   'Introduction to Machine Learning, Supervised Learning, Deep Learning, Unsupervised Learning',
#   'Intermediate Python',
#   'Kaggle, AWS',
#   'https://www.udacity.com/course/intro-to-machine-learning-nanodegree--nd229'),
#  ('AWS Cloud Architect',
#   'nanodegree',
#   'Build confidence planning, designing, and creating high availability cloud infrastructure.',
#   'advanced',
#   '3 Months',
#   4.6,
#   277,
#   'Cloud Infrastructure, Cloud Security, AWS, CloudFormation, High Availability Infrastructure, Serverless Computing',
#   'Experience with Cloud Computing, Programming, and AWS',
#   None,
#   'https://www.udacity.com/course/aws-cloud-architect-nanodegree--nd063'),
#  ('AI for Business Leaders',
#   'nanodegree',
#   'Master the foundations of artificial intelligence so you can strategically implement machine learning technology in your organization, and leverage it for corporate growth.',
#   'intermediate',
#   '2 Months',
#   4.6,
#   124,
#   'Artificial Intelligence, Machine Learning, Business Strategy, Data Labeling, Data Modeling',
#   'Statistics, Probability, and Business Experience',
#   'BMW',
#   'https://www.udacity.com/course/ai-for-business-leaders--nd054'),
#  ('AI for Healthcare',
#   'nanodegree',
#   'Be at the forefront of the AI revolution in healthcare and transform patient outcomes by enabling enhanced medical decision-making powered by machine learning.',
#   'advanced',
#   '4 Months',
#   4.6,
#   145,
#   'Artificial Intelligence, 2D Medical Imaging, 3D Medical Imaging, Electronic Health Record Data, Deep Learning, Wearable Device Data, Supervised Learning',
#   'Intermediate Python, and Experience with Machine Learning',
#   None,
#   'https://www.udacity.com/course/ai-for-healthcare-nanodegree--nd320'),
#  ('iOS Developer',
#   'nanodegree',
#   'Master the Swift programming language, and create a portfolio of iOS apps for iPhone and iPad to showcase your skills!',
#   'beginner',
#   '6 Months',
#   4.6,
#   897,
#   'Swift programming, Core Data, UIKit, iOS networking, app publishing, User interfaces, Local Persistence, APIs',
#   'No prior knowledge required',
#   None,
#   'https://www.udacity.com/course/ios-developer-nanodegree--nd003'),
#  ('Flying Car and Autonomous Flight Engineer',
#   'nanodegree',
#   'Master job-ready autonomous flight software engineering skills as you tackle advanced challenges, write real code for real aircraft, and develop a systems understanding of the Flying Car full-stack.',
#   'advanced',
#   '6 Months',
#   4.6,
#   254,
#   '3D Motion Planning, Controls, Estimation, Kalman Filters',
#   'Mathematics & Programming',
#   None,
#   'https://www.udacity.com/course/flying-car-nanodegree--nd787'),
#  ('Artificial Intelligence',
#   'nanodegree',
#   'Learn essential Artificial Intelligence concepts from AI experts like Peter Norvig and Sebastian Thrun, including search, optimization, planning, pattern recognition, and more.',
#   'advanced',
#   '3 Months',
#   4.5,
#   355,
#   'Constraint Propagation,  AI Algorithms,  Constraint Satisfaction Problems,  Backtracking Search,  Optimization Algorithms,  Search Algorithms,  Minimax Search,  Bayesian networks,  Planning,  Pattern Recognition,  Time-Series Analysis with ML',
#   'Algebra, Calculus, Statistics, & Python',
#   None,
#   'https://www.udacity.com/course/ai-artificial-intelligence-nanodegree--nd898'),
#  ('Digital Project Management',
#   'nanodegree',
#   'Build confidence translating business requirements into project scope statements, creating project plans, and developing a high-performing team.\n',
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Waterfall project management,  Strategic communication plans,  Requirements gathering,  Project scoping,  Project execution,  Gantt charts,  Agile frameworks,  Stakeholder analysis,  SMART goals,  Team development,  Cost-benefit analysis',
#   'Professional fluency in English',
#   None,
#   'https://www.udacity.com/course/digital-project-management-nanodegree--nd043'),
#  ('Cloud Native Application Architecture',
#   'nanodegree',
#   'Learn to run and manage scalable applications in a cloud native environment using open source tools and projects like ArgoCD, gRPC, and Grafana.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   151,
#   'Microservice architecture,  Kubernetes,  Continuous Integration,  Continuous Delivery,  Message Passing,  Observability,  Microservices security',
#   'HTTP, Python, Git, Linux, Docker',
#   'SUSE',
#   'https://www.udacity.com/course/cloud-native-application-architecture-nanodegree--nd064'),
#  ('Data Visualization',
#   'nanodegree',
#   'Combine data, visuals, and narrative to tell impactful stories and make data-driven decisions.',
#   'beginner',
#   '4 Months',
#   4.6,
#   206,
#   'Data Visualization, Tableau, Dashboards, Data Storytelling',
#   'Basic Data Analysis',
#   None,
#   'https://www.udacity.com/course/data-visualization-nanodegree--nd197'),
#  ('Marketing Analytics',
#   'nanodegree',
#   'Learn to collect and analyze data, model marketing scenarios, and communicate your findings with Excel, Tableau, Google Analytics, and Data Studios.',
#   'beginner',
#   '3 Months',
#   4.6,
#   359,
#   'Google Analytics, Excel & Spreadsheets, Data Visualization, Customer Segmentation',
#   'No Prerequisites',
#   None,
#   'https://www.udacity.com/course/marketing-analytics-nanodegree--nd028'),
#  ('Cloud Architect using Microsoft Azure',
#   'nanodegree',
#   'Meet the growing demand for Azure cloud architects and learn the skills to translate business requirements into technical specifications for reliable, scalable, and secure cloud infrastructure using Microsoft Azure.',
#   'advanced',
#   '3 Months',
#   4.8,
#   94,
#   'Azure Security Center,  Azure Resource Manager,  Azure Pricing Calculator,  Azure Key Vault,  Azure Defender,  Cloud Cost Policies,  Cloud Cost Evaluation,  Automated Cloud Cost Optimization,  Privileged Identity Management,  Identity and Access Management Fundamentals,  Disaster Recovery Plans',
#   'Experience with cloud computing, programming and Microsoft Azure',
#   'Microsoft',
#   'https://www.udacity.com/course/cloud-architect-using-microsoft-azure-nanodegree--nd090'),
#  ('Ethical Hacker',
#   'nanodegree',
#   'Learn how to find and exploit vulnerabilities, design and execute penetration testing plans, and report on test findings.',
#   'advanced',
#   '2 Months',
#   None,
#   None,
#   'Vulnerability Management,  Penetration Testing,  Reconnaissance,  Social Engineering,  Open-source intelligence,  System and Application Auditing',
#   'Linux, Networking, Programming and Window OS',
#   None,
#   'https://www.udacity.com/course/ethical-hacker-nanodegree--nd350'),
#  ('RPA Developer with UiPath',
#   'nanodegree',
#   'Build the operational processes that enable the businesses of the future.',
#   'beginner',
#   '4 Months',
#   None,
#   None,
#   'Process Automation, Business Operations, UiPath Studio, UiPath Orchestrator',
#   'Basic familiarity with Microsoft applications and data manipulation',
#   'UiPath',
#   'https://www.udacity.com/course/rpa-developer-nanodegree--nd340'),
#  ('Privacy Engineer',
#   'nanodegree',
#   'Master the skills necessary to become a successful privacy engineer. Learn to create technical solutions and implement privacy principles by integrating Privacy-by-Design into product development, data infrastructure, and software release lifecycles.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Privacy by Design Framework,  Data Minimization,  Data Encryption,  Sensitive Data Tracking,  Hashing,  Privacy Risk Assessment,  Data Privacy Fundamentals,  Data Anonymization,  k-anonymization,  Data Privacy Regulations,  Tiers of Deletion,  Redaction for Data Minimization,  Regional Privacy Regulations,  Data Lifecycle Management',
#   'Python and SQL',
#   None,
#   'https://www.udacity.com/course/privacy-engineer-nanodegree--nd325'),
#  ('Machine Learning Engineer for Microsoft Azure',
#   'nanodegree',
#   'Strengthen your machine learning skills and build practical experience by training, validating, and evaluating models using Azure Machine Learning. ',
#   'intermediate',
#   '3 Months',
#   4.4,
#   200,
#   'Azure Machine Learning, Azure Machine Learning SDK, Automation with Pipelines, Automated ML, Machine Learning Operations\n',
#   'Prior experience with Python, Machine Learning, and Statistics',
#   'Microsoft',
#   'https://www.udacity.com/course/machine-learning-engineer-for-microsoft-azure-nanodegree--nd00333'),
#  ('Data Science for Business Leaders',
#   'nanodegree',
#   'Master the people, platforms, and processes required to leverage the power of Data Science in your business.',
#   'intermediate',
#   '2 Months',
#   4.4,
#   83,
#   'Business Strategy, Data Science, Data Architecture, Machine Learning, Human Capital',
#   'Statistics, Probability, and Business Experience',
#   'Alteryx',
#   'https://www.udacity.com/course/data-science-for-business-leaders--nd045'),
#  ('Security Engineer',
#   'nanodegree',
#   'Take advantage of the growing need for skilled security professionals by mastering the sought-after skills to protect an organization’s computer networks and systems from security threats or attacks.',
#   'intermediate',
#   '4 Months',
#   4.7,
#   57,
#   'Cryptography, Risk Evaluation, Authentication, Authorization, Access\nManagement, Penetration Testing',
#   'Basics of Python, experience configuring AWS and Linux environments',
#   None,
#   'https://www.udacity.com/course/security-engineer-nanodegree--nd698'),
#  ('Site Reliability Engineer',
#   'nanodegree',
#   'Learn to build automation tools that ensure designed solutions respond to requirements such as availability, performance, security, and maintainability.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Cost-Benefit Analysis,  Building SRE Teams,  Observability Best Practices,  Prometheus,  Grafana,  Service Level Indicators,  Terraform,  \nGeo-Replication,  Self-Healing System Design,  Microservice Design,  Deployment Rollback,  Deployment Automation,  Cloud Automation,  Deployment Automation,  Incident Post-Mortems,  Incident Management,  Reliability Reviews,  Capacity Management',
#   'Python or Java, Bash or Powershell, Linux, UNIX Shell and SQL',
#   None,
#   'https://www.udacity.com/course/site-reliability-engineer-nanodegree--nd087'),
#  ('Cloud DevOps using Microsoft Azure',
#   'nanodegree',
#   'Learn how to deploy, test, and monitor cloud applications on Azure, one of the most popular cloud services platforms across the globe.',
#   'intermediate',
#   '3 Months',
#   4.3,
#   106,
#   'Infrastructure as Code,  Configuration Management,  Agile Planning,  Continuous Integration,  Continuous Delivery,  Test Automation,  Monitoring',
#   'Intermediate Python, familiarity with Linux shell scripting and cloud concepts',
#   'Microsoft',
#   'https://www.udacity.com/course/cloud-devops-using-microsoft-azure-nanodegree--nd082'),
#  ('Security Analyst',
#   'nanodegree',
#   'Learn to identify, correct, and respond to security weaknesses and incidents through open-ended projects that mimic workplace security challenges.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Security controls,  Defensible Network Architecture,  security threat mitigation,  threat modeling,  vulnerability assessment,  incident detection and handling',
#   'Experience with Python, SQL, and security fundamentals',
#   None,
#   'https://www.udacity.com/course/security-analyst-nanodegree--nd324'),
#  ('Digital Freelancer',
#   'nanodegree',
#   'The goal of the Digital Freelancer Nanodegree program is to prepare students to enter the digital marketplace by teaching key skills to create a successful digital business. Students will learn freelancing basics and essential skills as well as how to build their personal brand to start a successful online business in the global freelancing marketplace.',
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Portfolio Websites,  Professional Networking,  Resumes,  Social Media Presence,  Non-Disclosure Agreements,  Service Agreements,  Freelance Pricing Frameworks,  Invoicing,  Brand Design,  Elevator pitches,  Formal Written Communication,  Project management tools,  Project scoping',
#   'Basic computer skills',
#   None,
#   'https://www.udacity.com/course/digital-freelancer-nanodegree--nd083'),
#  ('Cloud Developer using Microsoft Azure',
#   'nanodegree',
#   'Master critical cloud computing skills used to deploy, build, migrate, and monitor applications on Azure.',
#   'intermediate',
#   '4 Months',
#   4.4,
#   65,
#   'Virtual Machines,  App Services,  Microservices,  Serverless Functions,  Cloud Migration',
#   'Intermediate programming experience, familiarity with SQL databases and Git',
#   'Microsoft',
#   'https://www.udacity.com/course/cloud-developer-using-microsoft-azure-nanodegree--nd081'),
#  ('Golang',
#   'course',
#   'Discover Golang’s implementation of traditional programming features, as well as extra features that make it a powerful tool.',
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Go programming,  Go language fundamentals,  Go environment,  basic backend,  Goroutines,  web server,  REST API',
#   'Basic computer programming',
#   None,
#   'https://www.udacity.com/course/golang--cd11970'),
#  ('Data Privacy',
#   'course',
#   'Equip yourself with industry-guided data privacy best practices for physical or virtual office environments.',
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Privacy Impact Assessments,  Data privacy fundamentals,  Data privacy classification,  Data privacy governance,  Data privacy checklists,  Data privacy best practices,  Data loss prevention,  Technical cybersecurity controls,  Procedural cybersecurity controls,  Cybersecurity controls,  NIST Cybersecurity framework,  Data privacy regulations',
#   'Understanding of data privacy regulations and cybersecurity best practices',
#   None,
#   'https://www.udacity.com/course/data-privacy--cd1826'),
#  ('Cloud Computing for Business Leaders',
#   'nanodegree',
#   'Focus on the unique knowledge and skills that business leaders need to unlock the value of cloud technologies in their organizations.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Digital transformation,  leadership,  management,  cloud governance model,  novel cloud services,  operational efficiencies,  cloud center of excellence',
#   'Word Processors, Spreadsheets, Presentation Tools',
#   None,
#   'https://www.udacity.com/course/cloud-computing-for-business-leaders-nanodegree--nd046'),
#  ('Security Architect',
#   'nanodegree',
#   'The goal of the Security Architect Nanodegree is to equip learners with the necessary skills to implement elements of security infrastructure design and management at an enterprise level.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Threat Modeling,  DiD Framework,  Cybersecurity Risk Management,  Incident Response Playbooks,  Network Security Fundamentals,  Architecture Diagramming,  Access Control Matrices',
#   'Linux and AWS',
#   None,
#   'https://www.udacity.com/course/security-architect-nanodegree--nd992'),
#  ('Enterprise Security',
#   'nanodegree',
#   'This program addresses security topics related to corporate environments, which are often distinct from production environments and center around the devices, identities, and infrastructure used by personnel on a daily basis.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Device Hardening Strategy,  Cybersecurity Policy Writing,  Zero Trust Security Model,  Data Encryption,  Backup Strategy,  API Security,  Cloud Hardening Strategy,  Container Vulnerability Management,  IT Asset Management,  Secure Network Architecture Design,  Cybersecurity Compliance',
#   'Linux and Azure',
#   None,
#   'https://www.udacity.com/course/enterprise-security-nanodegree--nd0035'),
#  ('AI Engineer using Microsoft Azure',
#   'nanodegree',
#   'Master the skills necessary to implement machine learning models, build end-to-end AI solutions, and manage continuous improvement of an Azure AI solution.',
#   'advanced',
#   '3 Months',
#   None,
#   None,
#   'Object Detection,  Image Classification,  Form Recognition,  Facial Recognition,  Face Detection,  Azure Cognitive Services,  Microsoft Bot Framework,  Azure Conversational AI Agents,  Architecture Diagramming,  Requirements Gathering,  Intent Recognition,  Key Phrase Extraction,  Azure Form Recognizer,  Bounding Boxes',
#   'Python, Microsoft Azure, JSON and REST programming semantics',
#   'Microsoft',
#   'https://www.udacity.com/course/ai-engineer-using-microsoft-azure--nd073'),
#  ('Programming for Data Science with R',
#   'nanodegree',
#   'Prepare for a data science career by learning the fundamental data programming tools: R, SQL, command line, and git.',
#   'beginner',
#   '3 Months',
#   4.8,
#   95,
#   'R, SQL, Git',
#   'None',
#   'Mode',
#   'https://www.udacity.com/course/programming-for-data-science-nanodegree-with-R--nd118'),
#  ('Zero Trust Security',
#   'course',
#   'Learners leave the course with a reinvigorated perspective on cybersecurity and a lexicon of practices and solutions that support what is rapidly becoming the new dominant strategy in enterprise security.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Zero Trust Pillars,  Zero Trust Security Model,  Zero Trust Deployment Strategy,  Zero Trust Maturity Model,  Zero Trust Algorithms,  Cybersecurity Risk Management,  Perimeter Security',
#   'Familiarity with basic cybersecurity concepts and practices',
#   None,
#   'https://www.udacity.com/course/zero-trust-security--cd11535'),
#  ('Cybersecurity for Business Leaders',
#   'nanodegree',
#   'Learn to leverage the capabilities of cybersecurity best practices to protect your organization and unlock next-level results.',
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Basic Cybersecurity Implementation,  Threat Actors,  Security Devices,  Vulnerability Assessment,  Security Risk Classification,  Cybersecurity Fluency,  Cybersecurity Risk Management,  Cybersecurity Training Strategies,  Social Engineering,  Phishing,  Cybersecurity incident response playbooks,  Cybersecurity Regulations and Standards',
#   'No prior experience is required',
#   None,
#   'https://www.udacity.com/course/cybersecurity-for-business-leaders--nd1202'),
#  ('Ethical AI',
#   'course',
#   'Learn to apply ethical AI to minimize bias, while maximizing fairness and explainability, ensuring an ethical future for all.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'AI Fairness,  AI Governance,  AI Transparency,  Model Bias Analysis,  Model Bias Mitigation,  Explainable AI,  Ethical AI',
#   'AI & machine learning fundamentals',
#   None,
#   'https://www.udacity.com/course/ethical-ai--cd1827'),
#  ('AWS Machine Learning Foundations Course',
#   'free',
#   'Learn what machine learning is and the steps involved in building and evaluating models. Gain in demand skills needed at businesses working to solve challenges with AI.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Computer vision,  Reinforcement learning,  Generative AI,  Machine Learning,  Object-oriented programming',
#   None,
#   None,
#   'https://www.udacity.com/course/aws-machine-learning-foundations--ud065'),
#  ('Introduction to Machine Learning using Microsoft Azure',
#   'free',
#   'Gain a high-level introduction to the field of machine learning and prepare to use Azure Machine Learning Studio to train machine learning models. Plus, learn how to perform a variety of tasks on Azure Machine Learning labs — from data import, transformation and management to training, validating and evaluating models.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Machine Learning,  Azure,  Model Training,  Supervised & Unsupervised Learning,  Responsible AI',
#   None,
#   'Microsoft Azure',
#   'https://www.udacity.com/course/introduction-to-machine-learning-using-microsoft-azure--ud00333'),
#  ('AI Fundamentals',
#   'free',
#   "AI Fundamentals is an entry point into the world of AI using Microsoft's cloud-based solutions, such as Azure Machine Learning and Azure Cognitive Services.",
#   'beginner',
#   '1 Month',
#   None,
#   None,
#   'Artificial Intelligence,  Machine Learning,  Azure,  Computer Vision,  Azure Cognitive Services,  Natural Language Processing,  Conversational AI',
#   None,
#   'Microsoft Azure',
#   'https://www.udacity.com/course/ai-fundamentals--ud099'),
#  ('Linear Algebra Refresher Course',
#   'free',
#   'Learn linear algebra by doing: you will code your own library of linear algebra functions!',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Algebra, Python, Vectors, Intersections',
#   None,
#   None,
#   'https://www.udacity.com/course/linear-algebra-refresher-course--ud953'),
#  ('Machine Learning: Unsupervised Learning',
#   'free',
#   "Ever wonder how Netflix can predict what movies you'll like? Or how Amazon knows what you want to buy before you do? The answer can be found in Unsupervised Learning!",
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Randomized Optimization, Clustering, Feature Selection, Feature Transformation, Information Theory',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/machine-learning-unsupervised-learning--ud741'),
#  ('Big Data Analytics in Healthcare',
#   'free',
#   'In this course, we introduce the characteristics of medical data and associated data mining challenges on dealing with such data. We cover various algorithms and systems.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Data Analytics, Health Care Applications, Algorithms',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/big-data-analytics-in-healthcare--ud758'),
#  ('Intel® Edge AI Fundamentals with OpenVINO™',
#   'free',
#   'Stay at the cutting-edge of AI technology by gaining practical skills for deploying edge AI. Learn how to use the Intel Distribution of OpenVINO toolkit to deploy computer vision capabilities inside a range of edge applications.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Edge AI, Intel OpenVINO, Computer Vision, Deep Learning',
#   None,
#   None,
#   'https://www.udacity.com/course/intel-edge-AI-fundamentals-with-openvino--ud132'),
#  ('Artificial Intelligence',
#   'free',
#   'This course gives a survey of topics in AI along with in-depth foundational concepts such as classical search, probability, machine learning, logic and planning.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Artificial Intelligence, Probability, Bayesian Networks, Logic and Planning, Machine Learning',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/artificial-intelligence--ud954'),
#  ('Secure and Private AI',
#   'free',
#   'Learn how to extend PyTorch with the tools necessary to train AI models that preserve user privacy.',
#   'advanced',
#   '2 Months',
#   None,
#   None,
#   'Artificial Intelligence, Probability, Bayesian Networks, Logic and Planning, Machine Learning',
#   None,
#   'Facebook AI',
#   'https://www.udacity.com/course/secure-and-private-ai--ud185'),
#  ('Model Building and Validation',
#   'free',
#   'This course will teach you how to start from scratch in understanding and paying attention to what is important in the data and how to answer questions about data.',
#   'advanced',
#   '8 Weeks',
#   None,
#   None,
#   'Questioning, Modeling, Validation, Data Analysis, QMV Process',
#   None,
#   'AT&T',
#   'https://www.udacity.com/course/model-building-and-validation--ud919'),
#  ('Data Visualization and D3.js',
#   'free',
#   'Learn the fundamentals of data visualization and apply design and narrative concepts to create your own visualization.',
#   'intermediate',
#   '7 Weeks',
#   None,
#   None,
#   'd3.js, Design of Visualizations, Data Visualization, Visual Encodings',
#   None,
#   'Zipfian',
#   'https://www.udacity.com/course/data-visualization-and-d3js--ud507'),
#  ('Machine Learning for Trading',
#   'free',
#   'Implement machine learning based strategies to make trading decisions using real-world data.',
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Pandas, Time Series Analysis, Computational Investing, Algorithmic Trading, Reinforcement Learning for Trading',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/machine-learning-for-trading--ud501'),
#  ('Machine Learning',
#   'free',
#   "In this course, you'll learn how to apply Supervised, Unsupervised and Reinforcement Learning techniques for solving a range of data science problems.",
#   'intermediate',
#   '4 Months',
#   None,
#   None,
#   'Supervised Learning, Unsupervised Learning, Information Theory, Reinforcement Learning, Game Theory',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/machine-learning--ud262'),
#  ('Intro to Hadoop and MapReduce',
#   'free',
#   'In this short course, learn the fundamentals of MapReduce and Apache Hadoop to start making sense of Big Data in the real world!',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Big Data, Hadoop, MapReduce',
#   None,
#   'Cloudera',
#   'https://www.udacity.com/course/intro-to-hadoop-and-mapreduce--ud617'),
#  ('Real-Time Analytics with Apache Storm',
#   'free',
#   'The world is trending in real time! Learn Apache Storm, taught by Twitter, to scalably analyze real-time tweets and drive d3 visualizations. Storm is free, open and fun!',
#   'intermediate',
#   '2 Weeks',
# ...
#   'free',
#   'Master how to work with big data and build machine learning models at scale using Spark!',
#   'intermediate',
#   '10 Hours',
#   None,
#   None,
#   'Spark, SparkSQL, Spark Dataframes, Data Wrangling, Machine Learning',
#   None,
#   'Insight',
#   'https://www.udacity.com/course/learn-spark-at-udacity--ud2002'),
#  ('Data Analysis and Visualization',
#   'free',
#   'This course will introduce students to the field by covering state\xad-of-\xadthe-art modeling, analysis and visualization techniques.',
#   'intermediate',
#   '16 Weeks',
#   None,
#   None,
#   'R, Data Analysis, Data Visualization, Regression',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/data-analysis-and-visualization--ud404'),
#  ('Introduction to Digital Project Management',
#   'free',
#   'This course introduces the field of digital project management, while diving into relevant career paths and what exactly those paths entail. It also covers the basic structure on which digital projects are formed.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'Digital project management basics,  project management skills,   project management lifecycle',
#   None,
#   None,
#   'https://www.udacity.com/course/introduction-to-digital-project-management--ud043'),
#  ('Getting Started with Google Workspace',
#   'free',
#   'Learn how to manage mail and schedules effectively. Create, manage and, share content in Google Drive and become more productive through the use of the collaboration features that are an integral and defining part of Google Workspace.',
#   'beginner',
#   '2 Months',
#   None,
#   None,
#   'Gmail,  Google Calendar,  Google Drive,  Google Docs,  Google Slides,  Google Meet,  Google Chat,  Google Forms,  Intermediate Spreadsheet Use,  Basic Spreadsheet Use',
#   None,
#   'Google Cloud',
#   'https://www.udacity.com/course/getting-started-with-google-workspace--ud300'),
#  ('Rapid Prototyping',
#   'free',
#   'Learning to prototype will save you time and money in the development process. You’ll create quality apps faster and have confidence in the viability of your products.',
#   'intermediate',
#   '3 Weeks',
#   None,
#   None,
#   'Prototyping, User Research, inVision',
#   None,
#   'Google',
#   'https://www.udacity.com/course/rapid-prototyping--ud723'),
#  ('Creating an Analytical Dataset',
#   'free',
#   'Learn how to prepare data to ensure the efficacy of your analysis while improving fluency in Alteryx.',
#   'beginner',
#   '2 Weeks',
#   None,
#   None,
#   'Data Issues, Data Formatting, Data Blending',
#   None,
#   'Alteryx',
#   'https://www.udacity.com/course/creating-an-analytical-dataset--ud977'),
#  ('Problem Solving with Advanced Analytics',
#   'free',
#   'Learn a scientific approach to solving problems with data, a foundational skill for anyone interested in making data driven decisions in a business context.',
#   'beginner',
#   '2 Weeks',
#   None,
#   None,
#   'Linear Regression',
#   None,
#   'Alteryx',
#   'https://www.udacity.com/course/problem-solving-with-advanced-analytics--ud976'),
#  ('Classification Models',
#   'free',
#   'Learn how to use classification predictive models to solve business problems involving non-numeric data.',
#   'intermediate',
#   '2 Weeks',
#   None,
#   None,
#   'Binary Classication Models, Non-Binary Classification Models',
#   None,
#   'Alteryx',
#   'https://www.udacity.com/course/classification-models--ud978'),
#  ('Product Design',
#   'free',
#   'Learn product validation, UI/UX practices, Google’s Design Sprint and the process for setting and tracking actionable metrics.',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Product Design, Design Sprints, Ideation and Validation, UI/UX',
#   None,
#   'Google',
#   'https://www.udacity.com/course/product-design--ud509'),
#  ('Segmentation and Clustering',
#   'free',
#   'The Segmentation & Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.',
#   'intermediate',
#   '3 Weeks',
#   None,
#   None,
#   'Variable Reduction, Clustering Models design',
#   None,
#   None,
#   'https://www.udacity.com/course/segmentation-and-clustering--ud981'),
#  ('Time Series Forecasting',
#   'free',
#   'The Time Series Forecasting course provides students with the foundational knowledge to build and apply time series forecasting models in a variety of business contexts.',
#   'intermediate',
#   '3 Weeks',
#   None,
#   None,
#   'Time Series Forecasting, ETS Models, ARIMA Models',
#   None,
#   None,
#   'https://www.udacity.com/course/time-series-forecasting--ud980'),
#  ('App Marketing',
#   'free',
#   'This course will help you organize a strategy of identifying your perfect user, and teach you how to grow your user base by focusing your product on their needs.',
#   'intermediate',
#   '2 Weeks',
#   None,
#   None,
#   'App Marketing, User Segmentation, Customer Acquisition',
#   None,
#   'Google',
#   'https://www.udacity.com/course/app-marketing--ud719'),
#  ('App Monetization',
#   'free',
#   'Learn how to effectively develop, implement, and measure your monetization strategy, iterating on the model as appropriate.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Product Design, Google Analytics',
#   None,
#   'Google',
#   'https://www.udacity.com/course/app-monetization--ud518'),
#  ('A/B Testing for Business Analysts',
#   'free',
#   'The A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision making.',
#   'intermediate',
#   '3 Weeks',
#   None,
#   None,
#   'A/B Randomized Design Tests, A/B Matched Pair Design Tests',
#   None,
#   None,
#   'https://www.udacity.com/course/ab-testing--ud979'),
#  ('How to Build a Startup',
#   'free',
#   'Learn what it takes to build a successful startup using the Customer Development process, where entrepreneurs "get out of the building" to gather and iterate on feedback.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Entrepreneurship, Value Proposition, Revenue Models, Customer Segments',
#   None,
#   None,
#   'https://www.udacity.com/course/how-to-build-a-startup--ep245'),
#  ('Get Your Startup Started',
#   'free',
#   'Acquire the know-how necessary to see your business grow towards its next milestone.',
#   'intermediate',
#   '3 Weeks',
#   None,
#   None,
#   'Entrepreneurship, Bootstrapping',
#   None,
#   'Google',
#   'https://www.udacity.com/course/get-your-startup-started--ud806'),
#  ('Managing Remote Teams with Upwork',
#   'free',
#   'Bring your remote-teams to the next level with hands-on skills to manage your remote workforce effectively.',
#   'beginner',
#   '1 Hour',
#   None,
#   None,
#   'Team Management, Workforce Training, Business Strategy, Agile Management, Remote Work',
#   None,
#   'Upwork',
#   'https://www.udacity.com/course/managing-remote-teams-with-upwork--ud942'),
#  ('Oracle Autonomous Database Administration',
#   'free',
#   'Dive into the fundamentals of autonomous databases. Explore the process of planning, implementing, and deploying an Oracle Autonomous Database, the first and only autonomous database service in the cloud.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'Oracle Autonomous Database,  Exadata infrastructure,  Oracle Machine Learning,  APEX,  and SQL Developer Web,  Autonomous JSON,  Oracle Text,  Spatial,  and Graph',
#   None,
#   'Oracle',
#   'https://www.udacity.com/course/oracle-autonomous-database-administration--cd12502'),
#  ('Oracle Cloud Infrastructure Architect Associate',
#   'free',
#   'Develop key insights into key concepts and features of Oracle Cloud Infrastructure (OCI).',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'VCN,  Network security,  load balancer and traffic management,  OCI Compute and storage,  autoscaling,  OS management',
#   None,
#   'Oracle',
#   'https://www.udacity.com/course/oracle-cloud-infrastructure-architect-associate--cd12503'),
#  ('Oracle Cloud Infrastructure Architect Professional',
#   'free',
#   'This course will help you gain strong knowledge through hands-on experience with architecting infrastructure using Oracle Cloud Infrastructure services.',
#   'advanced',
#   '1 Week',
#   None,
#   None,
#   'OCI,  Cloud solution,  N-tier applications,  microservices,  and serverless architecture',
#   None,
#   'Oracle',
#   'https://www.udacity.com/course/oracle-cloud-infrastructure-architect-professional--cd12504'),
#  ('Oracle Cloud Infrastructure Foundations',
#   'free',
#   'Develop foundational knowledge of Oracle Cloud Infrastructure Cloud Services.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'OCI,  OCI service offerings,  OCI security model,  OCI compliance structure,  OCI pricing,  support model,  and operations.',
#   None,
#   'Oracle',
#   'https://www.udacity.com/course/oracle-cloud-infrastructure-foundations--cd12505'),
#  ('Oracle Cloud Infrastructure Operations Professional',
#   'free',
#   'This course is going to walk you through some of the day-to-day operational activities that you might find yourself managing in the Oracle Cloud Infrastructure ecosystem.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'OCI CLI,  Oracle Resource Manager,  Manage custom images,  Network Security Architecture',
#   None,
#   'Oracle',
#   'https://www.udacity.com/course/oracle-cloud-infrastructure-operations-professional--cd12506'),
#  ('Google Cloud Digital Leader Training',
#   'free',
#   'Gain foundational literacy in cloud & digital transformation. Increase your cloud confidence so you can speak with colleagues in technical cloud roles and contribute to informed cloud-related business decisions.',
#   'intermediate',
#   '2 Weeks',
#   None,
#   None,
#   'Google Cloud Fundamentals,  Cloud Computing Fluency,  Digital Transformation Strategy,  Data Innovation,  IT Infrastructure Modernization,  Application Modernization,  Cloud Cost Governance,  Cloud Security Fluency,  Cloud Operational Efficiency',
#   None,
#   'Google Cloud',
#   'https://www.udacity.com/course/google-cloud-digital-leader-training--ud301'),
#  ('Cloud Native Fundamentals',
#   'free',
#   'Throughout this course, students will learn how to structure, package, and release an application to a Kubernetes cluster, while using an automated CI/CD pipeline.',
#   'intermediate',
#   '1 Month',
#   None,
#   None,
#   'Kubernetes,  Docker,  Cloud Computing Fluency,  Cloud Architecture Model Types,  CI/CD,  Application Development Best Practices,  Argo CD,  Github Actions,  Platform as a Service',
#   None,
#   'SUSE',
#   'https://www.udacity.com/course/cloud-native-fundamentals--ud064'),
#  ('Cyber-Physical Systems Design & Analysis',
#   'free',
#   'This course provides an introduction to cyber-physical systems with an industrial perspective.',
#   'advanced',
#   '16 Weeks',
#   None,
#   None,
#   'Kubernetes,  Docker,  Cloud Computing Fluency,  Cloud Architecture Model Types,  CI/CD,  Application Development Best Practices,  Argo CD,  Github Actions,  Platform as a Service',
#   None,
#   'Georgia Institute of Technology',
#   'https://www.udacity.com/course/cyber-physical-systems-design-analysis--ud9876'),
#  ('Differential Equations in Action',
#   'free',
#   'Write Python code to find numerical solutions to systems of differential equations. The models you create will fight wildfires, bring spaceships back to earth, and more!',
#   'intermediate',
#   '2 Months',
#   None,
#   None,
#   'Math, Differential Equations',
#   None,
#   None,
#   'https://www.udacity.com/course/differential-equations-in-action--cs222'),
#  ('Self-Driving Fundamentals: Featuring Apollo ',
#   'free',
#   'Identify key parts of self-driving cars, utilize Apollo HD Map, localization, perception, prediction, planning and control, and start the learning path of building a self-driving car. ',
#   'beginner',
#   '4 Weeks',
#   None,
#   None,
#   'Apollo HD Map, Localization, Perception, Prediction, Planning, Control',
#   None,
#   'Baidu',
#   'https://www.udacity.com/course/self-driving-car-fundamentals-featuring-apollo--ud0419'),
#  ('Product Manager Interview Preparation',
#   'free',
#   'Ace your product management interview by understanding how to answer key strategic, technical, and practical product questions.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'Product Management, Interview Preparation, Career Advancement, Product Strategy, Technical Interview',
#   None,
#   None,
#   'https://www.udacity.com/course/product-manager-interview-preparation--ud034'),
#  ('Craft Your Cover Letter',
#   'free',
#   'Write a compelling narrative that showcases your value to the company.',
#   'beginner',
#   '1 Day',
#   None,
#   None,
#   'Creating a narrative, Targeting your pitch, Communicating value, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/craft-your-cover-letter--ud244'),
#  ('Refresh Your Resume',
#   'free',
#   'Create a targeted resume that gets the attention of recruiters and lands you an interview in tech.',
#   'beginner',
#   '2 Days',
#   None,
#   None,
#   'Resume writing, Company targeting, Storytelling, Career Advancement',
#   None,
#   'Grow With Google',
#   'https://www.udacity.com/course/refresh-your-resume--ud243'),
#  ('Strengthen Your LinkedIn Network & Brand',
#   'free',
#   'Learn how to excel at networking both in-person and on LinkedIn.',
#   'beginner',
#   '1 Week',
#   None,
#   None,
#   'Personal branding, LinkedIn, Networking, Career Advancement',
#   None,
#   'Grow With Google',
#   'https://www.udacity.com/course/strengthen-your-linkedin-network-and-brand--ud242'),
#  ('Data Science Interview Prep',
#   'free',
#   'Prepare for data science interviews by practicing data analysis, machine learning, and data structure and algorithms questions.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Common Data Questions, Data Structures, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/data-science-interview-prep--ud944'),
#  ('Android Interview Prep',
#   'free',
#   'Learn how to respond to common Android and mobile development interview questions.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Common Android Questions, Whiteboarding',
#   None,
#   'Grow With Google',
#   'https://www.udacity.com/course/android-interview-prep--ud241'),
#  ('Machine Learning Interview Preparation',
#   'free',
#   'In this course, you’ll learn exactly what to expect during a machine learning interview.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Machine Learning, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/machine-learning-interview-prep--ud1001'),
#  ('Front-End Interview Prep',
#   'free',
#   'Answer front-end technical and behavioral interview questions with confidence and poise.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview questions, Common FE Questions, Whiteboarding, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/front-end-interview-prep--ud250'),
#  ('Full-Stack Interview Prep',
#   'free',
#   'Answer common full stack and web security interview questions with confidence and poise.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Common FS Questions, Whiteboarding, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/full-stack-interview-prep--ud252'),
#  ('Data Structures & Algorithms in Swift',
#   'free',
#   'Review and practice the skills technical interviewers expect you to know and learn how to explain your Swift solutions.',
#   'intermediate',
#   '4 Weeks',
#   None,
#   None,
#   'Interview practice, Swift, Data structures, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/data-structures-and-algorithms-in-swift--ud1011'),
#  ('iOS Interview Prep',
#   'free',
#   'Answer iOS and mobile development interview questions with confidence and poise.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Common iOS Questions, Whiteboarding, Career Advancement',
#   None,
#   None,
#   'https://www.udacity.com/course/ios-interview-prep--ud240'),
#  ('VR Interview Prep',
#   'free',
#   'Learn how to tackle interview questions for technical roles in VR Development.',
#   'intermediate',
#   '1 Week',
#   None,
#   None,
#   'Interview practice, Common VR Questions, Whiteboarding, Career Advancement',
#   None,
#   'Grow With Google',
#   'https://www.udacity.com/course/vr-interview-prep--ud251')]

# %%
cols = ["Title", "Type", "Description", "Level", "Duration", "Rating", "Review Count", "Skills Covered", "Prerequisites", "Affiliates", "URL"]
courses_df = pd.DataFrame(courses, columns=cols)
courses_df
# Out:
#                                      Title        Type  \
# 0                Data Engineering with AWS  nanodegree
# 1                          Product Manager  nanodegree
# 2                                      C++  nanodegree
# 3                       Business Analytics  nanodegree
# 4                           Data Scientist  nanodegree
# ..                                     ...         ...
# 262               Front-End Interview Prep        free
# 263              Full-Stack Interview Prep        free
# 264  Data Structures & Algorithms in Swift        free
# 265                     iOS Interview Prep        free
# 266                      VR Interview Prep        free
#
#                                            Description         Level  \
# 0    Learn to design data models, build data wareho...  intermediate
# 1    Envision and execute the development of indust...      beginner
# 2    Get hands-on experience building five real-wor...  intermediate
# 3    Gain foundational data skills like analyzing d...      beginner
# 4    Build effective machine learning models, run d...      advanced
# ..                                                 ...           ...
# 262  Answer front-end technical and behavioral inte...  intermediate
# 263  Answer common full stack and web security inte...  intermediate
# 264  Review and practice the skills technical inter...  intermediate
# 265  Answer iOS and mobile development interview qu...  intermediate
# 266  Learn how to tackle interview questions for te...  intermediate
#
#      Duration  Rating  Review Count  \
# 0    4 Months     4.6        1802.0
# 1    4 Months     4.7         864.0
# 2    4 Months     4.5        1126.0
# 3    3 Months     4.8        2649.0
# 4    4 Months     4.7        1212.0
# ..        ...     ...           ...
# 262    1 Week     NaN           NaN
# 263    1 Week     NaN           NaN
# 264   4 Weeks     NaN           NaN
# 265    1 Week     NaN           NaN
# 266    1 Week     NaN           NaN
#
#                                         Skills Covered  \
# 0    AWS Glue,  Amazon S3,  AWS Data Warehouse,  Re...
# 1    Product Strategy, Product Design, Product Deve...
# 2    Data Structures & Algorithms, Memory Managemen...
# 3    Excel & Spreadsheets, SQL, Data Visualization,...
# 4    Machine Learning, Deep Learning, Software Engi...
# ..                                                 ...
# 262  Interview questions, Common FE Questions, Whit...
# 263  Interview practice, Common FS Questions, White...
# 264  Interview practice, Swift, Data structures, Ca...
# 265  Interview practice, Common iOS Questions, Whit...
# 266  Interview practice, Common VR Questions, White...
#
#                                          Prerequisites  \
# 0    Intermediate Python, intermediate SQL & comman...
# 1                               No Experience Required
# 2                             Intermediate Programming
# 3                                                 None
# 4                             Python, SQL & Statistics
# ..                                                 ...
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                               None
#
#                                             Affiliates  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 Mode
# 4    Bertelsmann, Figure Eight, IBM Watson, Insight...
# ..                                                 ...
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                   Grow With Google
#
#                                                    URL
# 0    https://www.udacity.com/course/data-engineer-n...
# 1    https://www.udacity.com/course/product-manager...
# 2    https://www.udacity.com/course/c-plus-plus-nan...
# 3    https://www.udacity.com/course/business-analyt...
# 4    https://www.udacity.com/course/data-scientist-...
# ..                                                 ...
# 262  https://www.udacity.com/course/front-end-inter...
# 263  https://www.udacity.com/course/full-stack-inte...
# 264  https://www.udacity.com/course/data-structures...
# 265  https://www.udacity.com/course/ios-interview-p...
# 266  https://www.udacity.com/course/vr-interview-pr...
#
# [267 rows x 11 columns]

# %%
courses_df.to_csv("./output/all_courses.csv", index=False)
courses_df
# Out:
#                                      Title        Type  \
# 0                Data Engineering with AWS  nanodegree
# 1                          Product Manager  nanodegree
# 2                                      C++  nanodegree
# 3                       Business Analytics  nanodegree
# 4                           Data Scientist  nanodegree
# ..                                     ...         ...
# 262               Front-End Interview Prep        free
# 263              Full-Stack Interview Prep        free
# 264  Data Structures & Algorithms in Swift        free
# 265                     iOS Interview Prep        free
# 266                      VR Interview Prep        free
#
#                                            Description         Level  \
# 0    Learn to design data models, build data wareho...  intermediate
# 1    Envision and execute the development of indust...      beginner
# 2    Get hands-on experience building five real-wor...  intermediate
# 3    Gain foundational data skills like analyzing d...      beginner
# 4    Build effective machine learning models, run d...      advanced
# ..                                                 ...           ...
# 262  Answer front-end technical and behavioral inte...  intermediate
# 263  Answer common full stack and web security inte...  intermediate
# 264  Review and practice the skills technical inter...  intermediate
# 265  Answer iOS and mobile development interview qu...  intermediate
# 266  Learn how to tackle interview questions for te...  intermediate
#
#      Duration  Rating  Review Count  \
# 0    4 Months     4.6        1802.0
# 1    4 Months     4.7         864.0
# 2    4 Months     4.5        1126.0
# 3    3 Months     4.8        2649.0
# 4    4 Months     4.7        1212.0
# ..        ...     ...           ...
# 262    1 Week     NaN           NaN
# 263    1 Week     NaN           NaN
# 264   4 Weeks     NaN           NaN
# 265    1 Week     NaN           NaN
# 266    1 Week     NaN           NaN
#
#                                         Skills Covered  \
# 0    AWS Glue,  Amazon S3,  AWS Data Warehouse,  Re...
# 1    Product Strategy, Product Design, Product Deve...
# 2    Data Structures & Algorithms, Memory Managemen...
# 3    Excel & Spreadsheets, SQL, Data Visualization,...
# 4    Machine Learning, Deep Learning, Software Engi...
# ..                                                 ...
# 262  Interview questions, Common FE Questions, Whit...
# 263  Interview practice, Common FS Questions, White...
# 264  Interview practice, Swift, Data structures, Ca...
# 265  Interview practice, Common iOS Questions, Whit...
# 266  Interview practice, Common VR Questions, White...
#
#                                          Prerequisites  \
# 0    Intermediate Python, intermediate SQL & comman...
# 1                               No Experience Required
# 2                             Intermediate Programming
# 3                                                 None
# 4                             Python, SQL & Statistics
# ..                                                 ...
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                               None
#
#                                             Affiliates  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 Mode
# 4    Bertelsmann, Figure Eight, IBM Watson, Insight...
# ..                                                 ...
# 262                                               None
# 263                                               None
# 264                                               None
# 265                                               None
# 266                                   Grow With Google
#
#                                                    URL
# 0    https://www.udacity.com/course/data-engineer-n...
# 1    https://www.udacity.com/course/product-manager...
# 2    https://www.udacity.com/course/c-plus-plus-nan...
# 3    https://www.udacity.com/course/business-analyt...
# 4    https://www.udacity.com/course/data-scientist-...
# ..                                                 ...
# 262  https://www.udacity.com/course/front-end-inter...
# 263  https://www.udacity.com/course/full-stack-inte...
# 264  https://www.udacity.com/course/data-structures...
# 265  https://www.udacity.com/course/ios-interview-p...
# 266  https://www.udacity.com/course/vr-interview-pr...
#
# [267 rows x 11 columns]
